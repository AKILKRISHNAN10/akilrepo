# %%
for i in range(0,10):
    print('square of ',i,' is ', i**2)
# Out:
# square of  0  is  0
# square of  1  is  1
# square of  2  is  4
# square of  3  is  9
# square of  4  is  16
# square of  5  is  25
# square of  6  is  36
# square of  7  is  49
# square of  8  is  64
# square of  9  is  81

# %%
items = ['apple','orange','mango','grapes']
find=input('enter the item name : ')
for i in items:
    if i==find:
        print(i,' is in stock')
        break
    else:
        print(i,' stock not available')
# Out:
# enter the item name :  mango
# apple  stock not available
# orange  stock not available
# mango  is in stock

# %%
items = ['apple','orange','mango','grapes']
find1=input('enter the item name : ')
find=find1.lower()

if find in items:
     print(find,' is in stock')
     
else:
     print(find,' stock not available')
# Out:
# enter the item name :  MANGO
# mango  is in stock

# %%
mark = [10,35,32,-65,100,145,52,95,99]
for i in mark:
    if i<0 or i>100:
        print(i,'upload stopped')
        break
    else:
        print(i,'upload completed')
# Out:
# 10 upload completed
# 35 upload completed
# 32 upload completed
# -65 upload stopped

# %%
mark = [10,35,32,-65,100,145,52,95,99]
for i in mark:
    if i<0 or i>100:
        
        continue
    else:
        print(i,'upload completed')
# Out:
# 10 upload completed
# 35 upload completed
# 32 upload completed
# 100 upload completed
# 52 upload completed
# 95 upload completed
# 99 upload completed

# %%
item1=['apple','mango','banana']



#item1.pop('carrot')

# %%
item1.append('carrot')

item1.sort()

# %%
item1.remove('carrot')

# %%
print(item1)
# Out:
# ['apple', 'banana', 'mango']

# %%
f='apple123'
for i in f:
    print(i)
# Out:
# a
# p
# p
# l
# e
# 1
# 2
# 3

# %%
f= input('enter the string:')
for i in f:
    if i.isdigit():
        pass
    elif i.isalpha():
        pass
    else:
        print('Letter:',i)`
# Out:
# enter the string: asd@lk152
# Letter: @

# %%
def sumadd(a,b,c):
    s1=a+b+c
    return(s1)

print(sumadd(1,5,6))
# Out:
# 12
