# %%
print('akil')
# Out:
# akil

# %%
a='akil'
b='krishnan'
print(a+b)
# Out:
# akilkrishnan

# %%
a='akil'
b='krishnan'`
print('a','b',sep=' ')
# Out:
# a b

# %%
print('akil','krishnan',end='\t')
# Out:
# akil krishnan

# %%
print('akil','k',sep='/')
# Out:
# akil/k

# %%
a=10
a+=1
print('a+= : ',a)
a-=1
print('a-= : ',a)
a*=2
print('a*= : ',a)
# Out:
# a+= :  11
# a-= :  10
# a*= :  20
