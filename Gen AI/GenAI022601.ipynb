# %%
# !pip install pandas

# %%
import pandas as pd

r=pd.read_csv(r"E:\Akil\Downloads\APS7AMYAMATHS.csv")
print(r)
# Out:
#     ROW_NUM ROLL_NUM                    NAME  PT_1_40  PT_1_5 PT_2_40 PT_2_5  \
# 0         1     7B01          AARTHIKA. P. N       40     5.0      35    4.3
# 1         2     7B02          AARTHIKAN. N.E       26     3.2      26    3.3
# 2         3     7B03       ADHES KIRUTHIK. T       16     1.9      21    2.6
# 3         4     7B04               HARISH. J       11     1.4      14    1.7
# 4         5     7B05      KANISHK PRITHVI. M       12     1.5      17    2.1
# 5         6     7B06             KANISKAA. S       35     4.3      29    3.6
# 6         7     7B07                KAVIN. P       24     3.0      26    3.3
# 7         8     7B08                KAVIN. T       15     1.8      13    1.6
# 8         9     7B09          KAVIYATHIES. S        7     0.8      13    1.6
# 9        10     7B10               KOWSIK. S       39     4.9      38    4.7
# 10       11     7B11           LOKITHA. V. A       17     2.1       A      A
# ...

# %%
# !pip install numpy

# %%
import  pandas as pd
import numpy as np

students = pd.read_csv(r"E:\Akil\Downloads\APS7AMYAMATHS.csv")

print('\n Students marks\n')
x = students['MYA_MARKS_80']=pd.to_numeric(students['MYA_MARKS_80'],errors='coerce')
x1 = pd.DataFrame(x)
print(x)
print(x1)
print(students['MYA_MARKS_80'].sum())
# Out:
#  Students marks
#
# 0     80.0
# 1     33.5
# 2     36.5
# 3     21.5
# 4     28.0
# 5     57.0
# 6     38.0
# 7     17.5
# 8     13.5
# 9     79.0
# 10    29.5
# 11    43.5
# 12    12.0
# 13    49.0
# 14    36.0
# 15    27.0
# 16    40.5
# 17    43.5
# 18    75.5
# 19    18.0
# 20    22.0
# 21    28.5
# 22     NaN
# 23    30.5
# 24    38.0
# 25    52.5
# Name: MYA_MARKS_80, dtype: float64
#     MYA_MARKS_80
# 0           80.0
# 1           33.5
# 2           36.5
# 3           21.5
# 4           28.0
# 5           57.0
# 6           38.0
# 7           17.5
# 8           13.5
# 9           79.0
# 10          29.5
# 11          43.5
# 12          12.0
# 13          49.0
# 14          36.0
# 15          27.0
# 16          40.5
# 17          43.5
# 18          75.5
# 19          18.0
# 20          22.0
# 21          28.5
# 22           NaN
# 23          30.5
# 24          38.0
# 25          52.5
# 950.5
